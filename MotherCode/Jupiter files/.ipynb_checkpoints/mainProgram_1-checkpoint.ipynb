# %%
# DECLARING REQUIRED PACKAGES
import numpy as np
import math
from scipy.constants import e, m_p

# DELCARING THE CLASS Particle
from particle import Particle

# DECLARING OUR methods FILE
import methods

# DECLARING OUR 2D-Plotter FILE
import plotter
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#============ FIXED ENERGY OF 200 eV: 2D PLOT ==============

# %%
# DECLARING AN ARRAY TO STORAGE OUR PARTICLES
particles = []
n = 1000 #Number of test particles

# ALPHA PARTICLE INFORMATION
m = 2*m_p
q = 2*e
E = 200 #eV

# RANGE OF POSITIONS FOR THE IMPACT PARAMETER b
y0 = 50e-4
y1 = 100e-4

# INITIAL HORIZONTAL DISTANCE TO THE PARTICLES AND THE TARGET
d = -0.02 #meters

# %%
# INSTANCING OUR 20 PARTICLES
for i in range(n):
    b1 = methods.b(y0,y1)
    b2 = - b1
    particles.append(Particle(m,q,[d,b1],[np.sqrt(b1**2+d**2),np.arctan2(b1,d)],E,b1))
    particles.append(Particle(m,q,[d,b2],[np.sqrt(b2**2+d**2),np.arctan2(b2,d)],E,b2))

# %%
# INSTANCING THE TARGET GOLD NUCLEUS AT THE ORIGIN
target = Particle(79*m_p,79*e,[0,0],[0,0],0,0)

# %%
# DEFINING INITIAL PARAMETERS FOR RK4
t1, t2, steps = 0, 0.00000018, 10000
h = abs(t2-t1)/steps

# %%
# MOVING THE PARTICLES USING RK4 METHOD
particles = methods.rutherford(particles, target,t1,t2,h)

# %%
#plotter.xyPlot(particles,target.getPositions())
plotter.trajectoryPlot(particles,target.getPositions())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-e4b90ee86d9a> in <module>
#       1 #plotter.xyPlot(particles,target.getPositions())
# ----> 2 plotter.trajectoryPlot(particles,target.getPositions())
#
# ~/Google Drive/RIT myCourses/2021 Spring/PHYS-377 Advanced Computational Physics/Final Project/Code/MotherCode/plotter.py in trajectoryPlot(particles, target_pos)
#      32     for particle in particles:
#      33         positions = particle.getPositions()
# ---> 34         p.line(positions[:,0], positions[:,1], line_width=2, color=particle.getColor())
#      35     citation = Label(x=395, y=225, x_units='screen', y_units='screen',
#      36                  text='Gold Nucleus', render_mode='css',
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/plotting/_decorators.py in wrapped(self, *args, **kwargs)
#      52             for arg, param in zip(args, sigparams[1:]):
#      53                 kwargs[param.name] = arg
# ---> 54             return create_renderer(glyphclass, self, **kwargs)
#      55
#      56         wrapped.__signature__ = Signature(parameters=sigparams)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/plotting/_renderer.py in create_renderer(glyphclass, plot, **kwargs)
#      89     glyph_visuals = pop_visuals(glyphclass, kwargs)
#      90     incompatible_literal_spec_values = []
# ---> 91     incompatible_literal_spec_values += _process_sequence_literals(glyphclass, kwargs, source, is_user_source)
#      92     incompatible_literal_spec_values += _process_sequence_literals(glyphclass, glyph_visuals, source, is_user_source)
#      93     if incompatible_literal_spec_values:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/plotting/_renderer.py in _process_sequence_literals(glyphclass, kwargs, source, is_user_source)
#     293             incompatible_literal_spec_values.append(var)
#     294         else:
# --> 295             source.add(val, name=var)
#     296             kwargs[var] = var
#     297
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/models/sources.py in add(self, data, name)
#     351                 n += 1
#     352             name = "Series %d"%n
# --> 353         self.data[name] = data
#     354         return name
#     355
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/wrappers.py in __setitem__(self, i, y)
#     342     # don't wrap with notify_owner --- notifies owners explicitly
#     343     def __setitem__(self, i, y):
# --> 344         return self.update([(i, y)])
#     345
#     346     def __copy__(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/wrappers.py in update(self, *args, **kwargs)
#     376         for (owner, descriptor) in self._owners:
#     377             hint = ColumnDataChangedEvent(owner.document, owner, cols=list(cols))
# --> 378             descriptor._notify_mutated(owner, old, hint=hint)
#     379
#     380         return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/descriptors.py in _notify_mutated(self, obj, old, hint)
#     865         # re-validate because the contents of 'old' have changed,
#     866         # in some cases this could give us a new object for the value
# --> 867         value = self.property.prepare_value(obj, self.name, value)
#     868
#     869         self._real_set(obj, old, value, hint=hint)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/bases.py in prepare_value(self, obj_or_cls, name, value)
#     322         try:
#     323             if validation_on():
# --> 324                 self.validate(value)
#     325         except ValueError as e:
#     326             for tp, converter in self.alternatives:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/container.py in validate(self, value, detail)
#     181         if value is not None:
#     182             if not (isinstance(value, dict) and \
# --> 183                     all(self.keys_type.is_valid(key) and self.values_type.is_valid(val) for key, val in value.items())):
#     184                 msg = "" if not detail else "expected an element of %s, got %r" % (self, value)
#     185                 raise ValueError(msg)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/container.py in <genexpr>(.0)
#     181         if value is not None:
#     182             if not (isinstance(value, dict) and \
# --> 183                     all(self.keys_type.is_valid(key) and self.values_type.is_valid(val) for key, val in value.items())):
#     184                 msg = "" if not detail else "expected an element of %s, got %r" % (self, value)
#     185                 raise ValueError(msg)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/bases.py in is_valid(self, value)
#     306         try:
#     307             if validation_on():
# --> 308                 self.validate(value, False)
#     309         except ValueError:
#     310             return False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/container.py in validate(self, value, detail)
#      76
#      77         if value is not None:
# ---> 78             if not (self._is_seq(value) and all(self.item_type.is_valid(item) for item in value)):
#      79                 if self._is_seq(value):
#      80                     invalid = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/container.py in <genexpr>(.0)
#      76
#      77         if value is not None:
# ---> 78             if not (self._is_seq(value) and all(self.item_type.is_valid(item) for item in value)):
#      79                 if self._is_seq(value):
#      80                     invalid = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/bases.py in is_valid(self, value)
#     305         '''
#     306         try:
# --> 307             if validation_on():
#     308                 self.validate(value, False)
#     309         except ValueError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bokeh/core/property/bases.py in validation_on()
#     482
#     483     '''
# --> 484     return Property._should_validate
#     485
#     486 #-----------------------------------------------------------------------------
#
# KeyboardInterrupt:

# %%
data = []
for particle in particles:
    angle = abs(particle.getScatteringAngle()*180/np.pi)
    data.append(angle)

# %%
import numpy as np
from bokeh.io import show, output_file
from bokeh.plotting import figure

hist, edges = np.histogram(data, density=True, bins=50)

p = figure()
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="white")

output_file("hist.html")
show(p)
# Out:
#   <div class="bk-root" id="b049b8d4-9a54-47cf-ae23-9079ac6ead81" data-root-id="6479"></div>
